# %%
from pyiron_atomistics import Project

# %%
pr = Project("test")

# %%
pr.remove_jobs(recursive=True, silently=True)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
job = pr.create.job.Lammps("lmp")

# %%
job.structure = pr.create.structure.ase.bulk("Al", cubic=True)

# %%
job.potential = '2009--Mendelev-M-I--Al-Mg--LAMMPS--ipr1'

# %%
job.server.cores = 2

# %%
job.run()
# Out:
# The job lmp was saved and received the ID: 1

# %%
pr.job_table()
# Out:
#    id    status chemicalformula  job subjob    projectpath project  \
# 0   1  finished             Al4  lmp   /lmp  /home/jovyan/   test/
#
#                    timestart                   timestop  totalcputime  \
# 0 2025-08-03 18:06:51.256525 2025-08-03 18:06:54.197067           2.0
#
#                                            computer hamilton hamversion  \
# 0  pyiron@jupyter-pyiron-dev-pyiron--x---eac31396#2   Lammps        0.1
#
#   parentid masterid
# 0     None     None
