# %%
from pyiron_base import Project, job

# %%
pr = Project("test")
pr.remove_jobs(recursive=True, silently=True)
# Out:
# 0it [00:00, ?it/s]

# %%
@job
def add(x, y):
    return sum([x, y])

# %%
job = add(x=1, y=3, pyiron_project=pr)

# %%
job.input
# Out:
# {'x': 1, 'y': 3}

# %%
job.server.run_mode.non_modal = True

# %%
future = job.pull()
# Out:
# The job add_be42121124d4f9be50e66e3fa02cbf18 was saved and received the ID: 1

# %%
pr.job_table()
# Out:
#    id     status chemicalformula                                   job  \
# 0   1  submitted            None  add_be42121124d4f9be50e66e3fa02cbf18
#
#                                   subjob    projectpath project  \
# 0  /add_be42121124d4f9be50e66e3fa02cbf18  /home/jovyan/   test/
#
#                    timestart timestop totalcputime  \
# 0 2025-08-03 15:54:47.744712     None         None
#
#                                            computer  \
# 0  pyiron@jupyter-jan-janssen-pyiro--x---7acfde14#1
#
#                      hamilton hamversion parentid masterid
# 0  PythonFunctionContainerJob        0.4     None     None

# %%
pr.wait_for_jobs()

# %%
future.result()
# Out:
# 4

# %%
pr.job_table()
# Out:
#    id    status chemicalformula                                   job  \
# 0   1  finished            None  add_be42121124d4f9be50e66e3fa02cbf18
#
#                                   subjob    projectpath project  \
# 0  /add_be42121124d4f9be50e66e3fa02cbf18  /home/jovyan/   test/
#
#                    timestart timestop totalcputime  \
# 0 2025-08-03 15:54:47.744712     None         None
#
#                                            computer  \
# 0  pyiron@jupyter-jan-janssen-pyiro--x---7acfde14#1
#
#                      hamilton hamversion parentid masterid
# 0  PythonFunctionContainerJob        0.4     None     None
